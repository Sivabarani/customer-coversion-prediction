# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/processed/train_session_features.csv") #D:\Guvi Project and files\ClickStream\data\processed\train_session_features.csv

# %%
sns.histplot(df["avg_price"])
plt.show()

# %%
sns.countplot(x="conversion", data=df)
plt.show()

# %%
sns.countplot(x="country", data=df)
plt.show()

# %%
sns.heatmap(df.corr(), cmap="coolwarm")
plt.show()
